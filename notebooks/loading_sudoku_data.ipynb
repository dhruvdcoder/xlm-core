# %%
from datasets import load_dataset

# Load the sudoku dataset from CSV files
dataset = load_dataset(
    "csv",
    data_files={
        "train": "/Users/dhruveshpatel/Files/IESL/NAR/code/xlm-learned-noise-mdlm/data/sudoku/train.csv",
        "test": "/Users/dhruveshpatel/Files/IESL/NAR/code/xlm-learned-noise-mdlm/data/sudoku/test.csv"
    }
)

print(dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['quizzes', 'solutions'],
#         num_rows: 100000
#     })
#     test: Dataset({
#         features: ['quizzes', 'solutions'],
#         num_rows: 1000
#     })
# })

# %%
# Inspect the training dataset
print("Train dataset:")
print(dataset["train"])
print("\nFirst example:")
print(dataset["train"][0])
# Out:
# Train dataset:
# Dataset({
#     features: ['quizzes', 'solutions'],
#     num_rows: 100000
# })
#
# First example:
# {'quizzes': '004300209005009001070060043006002087190007400050083000600000105003508690042910300', 'solutions': '864371259325849761971265843436192587198657432257483916689734125713528694542916378'}

# %%
# Inspect the test dataset
print("Test dataset:")
print(dataset["test"])
print("\nFirst test example:")
print(dataset["test"][0])
# Out:
# Test dataset:
# Dataset({
#     features: ['quizzes', 'solutions'],
#     num_rows: 1000
# })
#
# First test example:
# {'quizzes': '080050060460907108005000029970006500000872031300049000004025003010000480603100007', 'solutions': '789251364462937158135468729978316542546872931321549876894725613217693485653184297'}

# %%
# Show dataset features and example usage
print("Dataset features:")
print(dataset["train"].features)

print("\nExample quiz and solution:")
example = dataset["train"][0]
print(f"Quiz:     {example['quizzes']}")
print(f"Solution: {example['solutions']}")
